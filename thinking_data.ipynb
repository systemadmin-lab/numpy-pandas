# %%
import json

# %%
#load the data
def load_data(filename):
    with open(filename, 'r') as file:
        data = json.load(file)
    return data

# %%
data=load_data('store.json')

# %%
#clean and structure. the data
def clean_data(data):
    for id in data:
        price =id['price']
        
        print(price)

# %%
clean_data(data)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[24], line 1
# ----> 1 clean_data(data)
#
# Cell In[23], line 5, in clean_data(data)
#       3 for id in data:
#       4     price =id['price']
# ----> 5     if price < 0:
#       6         id['price'] = 0+id['price']*-1
#       7     print(price)
#
# TypeError: '<' not supported between instances of 'str' and 'int'
