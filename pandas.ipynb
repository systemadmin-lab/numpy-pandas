# %%
import pandas as pd

# %%
info = [
  { "id": 1, "product_name": "Sony WH-1000XM4", "category": "Electronics", "price": "348.00", "stock": 45, "rating": 4.8 },
  { "id": 1, "product_name": "Sony WH-1000XM4", "category": "electronics", "price": "$348.00", "stock": 45, "rating": 4.8 },
 
  { "id": 3, "product_name": "logitech MX Master 3S", "category": "Accessories", "price": 99, "stock": 120, "rating": "4.7" },
  { "id": 4, "product_name": "Kindle Paperwhite", "category": "Electronics", "price": -139.99, "stock": 0, "rating": 4.6 },
  { "id": 5, "product_name": "Sony WH-1000XM4", "category": "Electronics", "price": 348.0, "stock": 45, "rating": 4.8 },
  { "id": 6, "product_name": "Samsung T7 SSD", "category": "Storage", "price": "89.99", "stock": 15, "rating": 4.5 },
  { "id": 7, "product_name": "samsung T7 SSD", "category": "storage ", "price": 89.99, "stock": 15, "rating": 4.5 },
  { "id": 8, "product_name": "  Bose QuietComfort  ", "category": "Electronics", "price": 299.00, "stock": 8, "rating": 3 },
  { "id": 9, "product_name": "Dell UltraSharp 27", "category": "Monitors", "price": 549.00, "stock": 20, "rating": 4.8 },
  { "id": 10, "product_name": "DELL UltraSharp 27", "category": "monitors", "price": 549, "stock": "20", "rating": 4.8 },
  { "id": 11, "product_name": "Anker USB-C Hub", "category": "Accessories", "price": 35.00, "stock": 200, "rating": 4.4 },
  { "id": 12, "product_name": "Anker USB-C Hub", "category": "Accessories", "price": 35.00, "stock": 200, "rating": 4.4 },
  { "id": 13, "product_name": "Razer BlackWidow", "category": "Gaming", "price": "129.99 USD", "stock": 30, "rating": 4.6 },
  { "id": 14, "product_name": "Razer BlackWidow", "category": "Gaming gear", "price": 129.99, "stock": 30, "rating": 4.6 },
  { "id": 15, "product_name": "HP OfficeJet Pro", "category": "Printers", "price": 199.00, "stock": 5, "rating": 4.2 },
  { "id": 16, "product_name": "null", "category": "Electronics", "price": 0, "stock": 0, "rating": 0 },
  { "id": 17, "product_name": "iPad Pro 11", "category": "Tablets", "price": 799.00, "stock": 10, "rating": 4.9 },
  { "id": 18, "product_name": "iPad Pro 11", "category": "Tablets", "price": 799.00, "stock": 10, "rating": 4.9 },
  { "id": 19, "product_name": "Fitbit Charge 5", "category": "Wearables", "price": 149.95, "stock": 50, "rating": 4.3 },
  { "id": 20, "product_name": "FITBIT CHARGE 5", "category": "Wearables", "price": 149.95, "stock": 50, "rating": 4.3 },
  { "id": 21, "product_name": "Sony PlayStation 5", "category": "Gaming", "price": 499.00, "stock": 2, "rating": 4.9 },
  { "id": 22, "product_name": "Nintendo Switch", "category": "Gaming", "price": 299.00, "stock": -5, "rating": 4.7 },
  { "id": 23, "product_name": "GoPro HERO11", "category": "Cameras", "price": 399.00, "stock": 12, "rating": 4.8 },
  { "id": 24, "product_name": "Gopro HERO11", "category": "CAMERAS", "price": 399, "stock": 12, "rating": 4.8 },
  { "id": 25, "product_name": "Hydro Flask 32oz", "category": "Home", "price": "44.95", "stock": 100, "rating": 4.8 },
  { "id": 26, "product_name": "Yeti Rambler", "category": "Home", "price": 35.00, "stock": 80, "rating": 4.7 },
  { "id": 27, "product_name": "Yeti Rambler", "category": "Home", "price": 35.0, "stock": 80, "rating": 4.7 },
  { "id": 28, "product_name": "Logitech G Pro X", "category": "Audio", "price": 129.00, "stock": 7, "rating": 4.5 },
  { "id": 29, "product_name": "Blue Yeti Mic", "category": "Audio", "price": 129.00, "stock": 25, "rating": 4.6 },
  { "id": 30, "product_name": "Blue Yeti Mic", "category": "audio", "price": "129", "stock": 25, "rating": 4.6 }
]
df =pd.DataFrame(info)
print(df)
# Out:
#     id           product_name     category       price stock rating
# 0    1        Sony WH-1000XM4  Electronics      348.00    45    4.8
# 1    1        Sony WH-1000XM4  electronics     $348.00    45    4.8
# 2    3  logitech MX Master 3S  Accessories          99   120    4.7
# 3    4      Kindle Paperwhite  Electronics     -139.99     0    4.6
# 4    5        Sony WH-1000XM4  Electronics       348.0    45    4.8
# 5    6         Samsung T7 SSD      Storage       89.99    15    4.5
# 6    7         samsung T7 SSD     storage        89.99    15    4.5
# 7    8    Bose QuietComfort    Electronics       299.0     8      3
# 8    9     Dell UltraSharp 27     Monitors       549.0    20    4.8
# 9   10     DELL UltraSharp 27     monitors         549    20    4.8
# 10  11        Anker USB-C Hub  Accessories        35.0   200    4.4
# 11  12        Anker USB-C Hub  Accessories        35.0   200    4.4
# 12  13       Razer BlackWidow       Gaming  129.99 USD    30    4.6
# ...

# %%
df
# Out:
#     id           product_name     category       price stock rating
# 0    1        Sony WH-1000XM4  Electronics      348.00    45    4.8
# 1    1        Sony WH-1000XM4  electronics     $348.00    45    4.8
# 2    3  logitech MX Master 3S  Accessories          99   120    4.7
# 3    4      Kindle Paperwhite  Electronics     -139.99     0    4.6
# 4    5        Sony WH-1000XM4  Electronics       348.0    45    4.8
# 5    6         Samsung T7 SSD      Storage       89.99    15    4.5
# 6    7         samsung T7 SSD     storage        89.99    15    4.5
# 7    8    Bose QuietComfort    Electronics       299.0     8      3
# 8    9     Dell UltraSharp 27     Monitors       549.0    20    4.8
# 9   10     DELL UltraSharp 27     monitors         549    20    4.8
# 10  11        Anker USB-C Hub  Accessories        35.0   200    4.4
# 11  12        Anker USB-C Hub  Accessories        35.0   200    4.4
# 12  13       Razer BlackWidow       Gaming  129.99 USD    30    4.6
# ...

# %%
s = pd.Series([1,2,3,4,5])
print(s)
print(type(s))
# Out:
# 0    1
# 1    2
# 2    3
# 3    4
# 4    5
# dtype: int64
# <class 'pandas.core.series.Series'>

# %%
s[4]
# Out:
# np.int64(5)

# %%
#  list cophrehension
