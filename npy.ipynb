# %%
import numpy as np

# %%
#creat numpyarray
arr = np.array([1, 2, 3, 4, 5])
print("Numpy Array:", type(arr))
arr2 =np.array([1, 2, 3, 4, 5,'hello'])
print("Numpy Array with mixed types:", type(arr2), arr2.dtype)
# Out:
# Numpy Array: <class 'numpy.ndarray'>
# Numpy Array with mixed types: <class 'numpy.ndarray'> <U21
